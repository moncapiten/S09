# %% [markdown]
# # Generatore di sequenze di bit pseudocasuali- S09
#
# **Informazioni generali:** Realizzazione generatore pesudocasale
#
# Dettagli del setup:
# * MC14557B
# * CD4013B
# * AD2 per l'acquisizione dati
# * LED vari e pulsanti per controllare il corretto comportamento delle porte logiche
#
# ## Task 1 - Caratteristiche del CD4013B
#
# Datasheet CD4013B
#
# Utilizziamo il flip-flop 1 dell' integrato, collegando SET1 e RESET1 a massa, in modo da non attivarli spuriamente.
#
# Di seguito la piedinatura.

# %%
import fitz  # PyMuPDF
from PIL import Image
import matplotlib.pyplot as plt

# Function to convert a PDF page to an image
def pdf_page_to_image(pdf_path, page_num=0):
    pdf_document = fitz.open(pdf_path)
    page = pdf_document.load_page(page_num)  # Load the specified page
    pix = page.get_pixmap()  # Convert page to image
    img = Image.frombytes("RGB", [pix.width, pix.height], pix.samples)
    return img

# Function to display two PDF pages side by side
def display_pdfs_side_by_side(rows, cols, pdfList):
    # Convert all PDF pages to images
    imgList = []
    for pdf in pdfList:
        imgList.append(pdf_page_to_image(pdf))

    # Create a new figure for nxm subplots (n row, m columns)
    if cols == 1 and rows == 1:
        #img = pdf_page_to_image(pdf_path)
        plt.imshow(imgList[0])
        plt.axis('off')
        plt.show()
        return
    
    fig, axes = plt.subplots(rows, cols, figsize=(30, 15), squeeze=False)
    
    # Display the various images

    for i in range(rows):
        print(i)
        if cols == 1:
            try:
                axes[i].imshow(imgList[i])
                axes[i].axis('off')
            except:
                pass
        else:
            for j in range(cols):
                try:
                    axes[i][j].imshow(imgList[i*cols+j])
                    axes[i][j].axis('off')
                except:
                    pass
    plt.show()


# Provide the paths to your two PDFs
pdfList = ['Media/piedi_CD4013B.png']
rows = 1
cols = 2
display_pdfs_side_by_side(rows, cols, pdfList)
# Out:
# 0

# %% [markdown]
# ## Task 2 - Divisore di frequenza per due

# %%
pdfList = ['Media/divisore.png']
rows = 1
cols = 2
display_pdfs_side_by_side(rows, cols, pdfList)
# Out:
# 0

# %% [markdown]
# Come CLK usiamo un onda quadra tra 0V e 5V , configuriamo SET e RESET dei flip-flop come segue:
#
# Data001 Divisore di frequenza per 2. CH1 = CLK = W1, onda quadra 0-5V, 500Hz, CH2 = Q
#
# Data002 Divide la frequenza per 1.33, CH1 = CLK = W1, CH2 = uscita NAND, impostazioni come prima, tagliare 2 periodi buoni.

# %% [markdown]
# ## Task 3 - Diagramma di stato del divisore per due

# %% [markdown]
# ## Task 4 - Divisore di frequenza con porte NAND del CD4011

# %%
pdfList= ['Media/divisore_con_NAND.png']
rows = 1
cols = 2
display_pdfs_side_by_side(rows, cols, pdfList)
# Out:
# 0

# %% [markdown]
# ## Task 5 - Funzionamento MC14557

# %%
pdfList= ['Media/piedi_MC14557.png', 'Media/ABsel_MC14557.png']
rows = 1
cols = 2
display_pdfs_side_by_side(rows, cols, pdfList)
# Out:
# 0

# %%
pdfList= [ 'Media/superpiedi_MC14557.png']
rows = 1
cols = 2
display_pdfs_side_by_side(rows, cols, pdfList)
# Out:
# 0

# %% [markdown]
# spiegazione funzionamento MC14557 in massimo due frasi non un sospiro in più!

# %% [markdown]
# ## Task 6 - Misura tempo di propagazione del segnale lungo bit di varia lunghezza

# %%
pdfList= ['Media/circuitoXOR.png', 'Media/foto_portaXOR.jpeg']
rows = 1
cols = 2
display_pdfs_side_by_side(rows, cols, pdfList)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_27528\50359860.py in ?()
#       1 pdfList= ['Media/circuitoXOR.png', 'Media/foto_portaXOR.jpeg']
#       2 rows = 1
#       3 cols = 2
# ----> 4 display_pdfs_side_by_side(rows, cols, pdfList)
#
# ~\AppData\Local\Temp\ipykernel_27528\301558783.py in ?(rows, cols, pdfList)
#      14 def display_pdfs_side_by_side(rows, cols, pdfList):
#      15     # Convert all PDF pages to images
#      16     imgList = []
#      17     for pdf in pdfList:
# ---> 18         imgList.append(pdf_page_to_image(pdf))
#      19
#      20     # Create a new figure for nxm subplots (n row, m columns)
#      21     if cols == 1 and rows == 1:
#
# ~\AppData\Local\Temp\ipykernel_27528\301558783.py in ?(pdf_path, page_num)
#       6 def pdf_page_to_image(pdf_path, page_num=0):
# ----> 7     pdf_document = fitz.open(pdf_path)
#       8     page = pdf_document.load_page(page_num)  # Load the specified page
#       9     pix = page.get_pixmap()  # Convert page to image
#      10     img = Image.frombytes("RGB", [pix.width, pix.height], pix.samples)
#
# c:\Users\15-cs3054nl\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymupdf\__init__.py in ?(self, filename, stream, filetype, rect, width, height, fontsize)
#    2902                     self.page_count2 = extra.page_count_pdf
#    2903                 else:
#    2904                     self.page_count2 = extra.page_count_fz
#    2905         finally:
# -> 2906             JM_mupdf_show_errors = JM_mupdf_show_errors_old
#
# FileNotFoundError: no such file: 'Media/circuitoXOR.png'

# %% [markdown]
# ## Task 7 - Registro a scorrimento a n+1 bit

# %%
pdfList= ['Media/bistabile_rosa.jpeg', 'Media/bistabile_arancione.jpeg']
rows = 1
cols = 2
display_pdfs_side_by_side(rows, cols, pdfList)
# Out:
# 0

# %% [markdown]
# Si assembla successivamente un latch SR.
# Questo è un circuito bistabile con ingressi $ \overline{Set} $ e $ \overline{Reset} $, fintanto che questi sono entrambi alti si hanno le uscite $ Q $ e $ \overline{Q} $ fisse all'ultimo stato memorizzato, questo stato può poi essere abbassato( tramite Reset ) o alzato( attraverso Set).
# In caso siano entrambi gli ingressi eccitati si ottengono ambo le uscite alte, situazione che manca una definizione univoca.

# %% [markdown]
# ## Homework 1

# %% [markdown]
# ## Task 8 - Generatore pesudocasuale

# %% [markdown]
# ## Task 9 - Codice MATLAB

# %% [markdown]
# ## Task 10 - Test dei limiti del sistema

# %%
pdfList= ['Media/george_russell.mp4']
rows = 1
cols = 2
display_pdfs_side_by_side(rows, cols, pdfList)
